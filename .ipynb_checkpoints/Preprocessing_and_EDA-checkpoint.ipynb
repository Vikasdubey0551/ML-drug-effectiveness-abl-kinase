# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
! conda install -c rdkit rdkit -y
# Out:
# Requirement already satisfied: chembl_webresource_client in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (0.10.2)
# Requirement already satisfied: requests>=2.18.4 in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (2.22.0)
# Requirement already satisfied: requests-cache>=0.4.7 in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (0.5.2)
# Requirement already satisfied: easydict in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dubey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2020.4.5.2)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ## **Importing libraries**

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
from rdkit.Chem.MolStandardize import rdMolStandardize
from chembl_webresource_client.new_client import new_client
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu
import seaborn as sns
from IPython.display import display
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Search for Target ABL kinase protein**

# %%
target = new_client.target
target_query = target.search('abl kinase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references  \
# 0     [{'xref_id': 'P00521', 'xref_name': None, 'xre...
# 1     [{'xref_id': 'P00519', 'xref_name': None, 'xre...
# 2     [{'xref_id': 'P00520', 'xref_name': None, 'xre...
# 3     [{'xref_id': 'A1Z199', 'xref_name': None, 'xre...
# 4                                                    []
# ...                                                 ...
# 1134                                                 []
# 1135                                                 []
# 1136                                                 []
# 1137                                                 []
# 1138                                                 []
#
#                            organism                          pref_name  score  \
# 0     Abelson murine leukemia virus      Tyrosine-protein kinase V-ABL   23.0
# 1                      Homo sapiens        Tyrosine-protein kinase ABL   18.0
# 2                      Mus musculus        Tyrosine-protein kinase ABL   18.0
# 3                      Homo sapiens        BCR/ABL p210 fusion protein   17.0
# 4                      Homo sapiens             Bcr/Abl fusion protein   16.0
# ...                             ...                                ...    ...
# 1134                   Homo sapiens                             mTORC1    2.0
# 1135                   Homo sapiens               mTOR/FKBP12A/FKBP12B    2.0
# 1136                   Homo sapiens  Fibroblast growth factor receptor    1.0
# 1137                   Mus musculus  Fibroblast growth factor receptor    1.0
# 1138                   Homo sapiens                   DNA-PK/Ku70/Ku85    1.0
#
#       species_group_flag target_chembl_id  \
# 0                  False       CHEMBL5166
# 1                  False       CHEMBL1862
# 2                  False       CHEMBL3099
# 3                  False       CHEMBL6105
# 4                  False    CHEMBL2096618
# ...                  ...              ...
# 1134               False    CHEMBL4296661
# 1135               False    CHEMBL4296662
# 1136               False    CHEMBL2095217
# 1137               False    CHEMBL2111391
# 1138               False    CHEMBL4106136
#
#                                       target_components       target_type  \
# 0     [{'accession': 'P00521', 'component_descriptio...    SINGLE PROTEIN
# 1     [{'accession': 'P00519', 'component_descriptio...    SINGLE PROTEIN
# 2     [{'accession': 'P00520', 'component_descriptio...    SINGLE PROTEIN
# 3     [{'accession': 'A1Z199', 'component_descriptio...    SINGLE PROTEIN
# 4     [{'accession': 'P00519', 'component_descriptio...  CHIMERIC PROTEIN
# ...                                                 ...               ...
# 1134  [{'accession': 'P42345', 'component_descriptio...   PROTEIN COMPLEX
# 1135  [{'accession': 'P62942', 'component_descriptio...   PROTEIN COMPLEX
# 1136  [{'accession': 'P22607', 'component_descriptio...    PROTEIN FAMILY
# 1137  [{'accession': 'P21803', 'component_descriptio...    PROTEIN FAMILY
# 1138  [{'accession': 'P78527', 'component_descriptio...   PROTEIN COMPLEX
#
#       tax_id
# 0      11788
# 1       9606
# 2      10090
# 3       9606
# 4       9606
# ...      ...
# 1134    9606
# 1135    9606
# 1136    9606
# 1137   10090
# 1138    9606
#
# [1139 rows x 9 columns]

# %% [markdown]
# ### Select and retrieve bioactivity data for Tyrosine-ABL-kinase

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL1862'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *ABL kinase* (CHEMBL1862) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %% [markdown]
# ### Extracting IC50 data

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %% [markdown]
# ### Converting data to dataframe

# %%
df = pd.DataFrame.from_dict(res)
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       129828                  []    CHEMBL819326
# 1             None       146141                  []    CHEMBL806527
# 2             None       146143                  []    CHEMBL762575
#
#                                    assay_description assay_type bao_endpoint  \
# 0                         Inhibition of c-Abl kinase          B  BAO_0000190
# 1  Radioligand displacement assay for the binding...          B  BAO_0000190
# 2  Inhibition of [35S]-labeled SH2-GST Abl bindin...          B  BAO_0000190
#
#     bao_format              bao_label  \
# 0  BAO_0000357  single protein format
# 1  BAO_0000357  single protein format
# 2  BAO_0000219      cell-based format
#
#                                     canonical_smiles  ... target_organism  \
# 0            COc1ccc(-c2[nH]nc3c2C(=O)c2ccccc2-3)cc1  ...    Homo sapiens
# 1  CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@@...  ...    Homo sapiens
# 2  CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@@...  ...    Homo sapiens
#
#               target_pref_name target_tax_id text_value  toid  type units  \
# 0  Tyrosine-protein kinase ABL          9606       None  None  IC50    uM
# 1  Tyrosine-protein kinase ABL          9606       None  None  IC50    uM
# 2  Tyrosine-protein kinase ABL          9606       None  None  IC50    uM
#
#      uo_units upper_value  value
# 0  UO_0000065        None  725.0
# 1  UO_0000065        None    4.0
# 2  UO_0000065        None   16.0
#
# [3 rows x 43 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df = df[df.standard_value.notna()]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df['standard_value'] = df['standard_value'].astype(float)
df['bioactivity_class'] = df['standard_value'].map(lambda x : 'active' if x <= 1000 else ('inactive' if x >=10000 else 'intermediate'))

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value','bioactivity_class']
df = df[selection]
df.head(5)
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL281470            COc1ccc(-c2[nH]nc3c2C(=O)c2ccccc2-3)cc1
# 1        CHEMBL13462  CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@@...
# 2        CHEMBL13462  CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@@...
# 3       CHEMBL414123  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
# 4       CHEMBL414123  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
#
#    standard_value bioactivity_class
# 0        725000.0          inactive
# 1          4000.0      intermediate
# 2         16000.0          inactive
# 3         15000.0          inactive
# 4          2900.0      intermediate

# %%
df.canonical_smiles.replace('nan',np.nan, inplace=True)
df.dropna(inplace=True)

# %%
'''
function to estimate molecule Lipinski descriptors

'''

def lipinski(smiles, verbose=False):
    moldata= []
    problematic_smiles=[]
    for i,elem in enumerate(smiles):
        try:
            mol=Chem.MolFromSmiles(elem) 
            mol = rdMolStandardize.Cleanup(mol)
            moldata.append(mol)  
        except:
            problematic_smiles.append(i)
            pass
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return  descriptors,problematic_smiles

# %%
df_lipinski, problematic_smiles = lipinski(df.canonical_smiles)
# Out:
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:47:02] Initializing MetalDisconnector
# RDKit INFO: [21:47:02] Running MetalDisconnector
# RDKit INFO: [21:47:02] Initializing Normalizer
# RDKit INFO: [21:47:02] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# RDKit INFO: [21:48:23] Initializing MetalDisconnector
# RDKit INFO: [21:48:23] Running MetalDisconnector
# RDKit INFO: [21:48:23] Initializing Normalizer
# RDKit INFO: [21:48:23] Running Normalizer
# ...
# RDKit INFO: [21:48:29] Initializing MetalDisconnector
# RDKit INFO: [21:48:29] Running MetalDisconnector
# RDKit INFO: [21:48:29] Initializing Normalizer
# RDKit INFO: [21:48:29] Running Normalizer
# RDKit INFO: [21:48:29] Initializing MetalDisconnector
# RDKit INFO: [21:48:29] Running MetalDisconnector
# RDKit INFO: [21:48:29] Initializing Normalizer
# RDKit INFO: [21:48:29] Running Normalizer
# RDKit INFO: [21:48:29] Initializing MetalDisconnector
# RDKit INFO: [21:48:29] Running MetalDisconnector
# RDKit INFO: [21:48:29] Initializing Normalizer
# RDKit INFO: [21:48:29] Running Normalizer
# RDKit INFO: [21:48:29] Initializing MetalDisconnector
# RDKit INFO: [21:48:29] Running MetalDisconnector
# RDKit INFO: [21:48:29] Initializing Normalizer
# RDKit INFO: [21:48:29] Running Normalizer
# RDKit INFO: [21:48:29] Initializing MetalDisconnector
# RDKit INFO: [21:48:29] Running MetalDisconnector
# RDKit INFO: [21:48:29] Initializing Normalizer
# RDKit INFO: [21:48:29] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector
# RDKit INFO: [21:48:30] Running MetalDisconnector
# RDKit INFO: [21:48:30] Initializing Normalizer
# RDKit INFO: [21:48:30] Running Normalizer
# RDKit INFO: [21:48:30] Initializing MetalDisconnector

# %%
problematic_smiles
# Out:
# []

# %%
df_lipinski.head(10).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col1 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col1 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow3_col0 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow4_col0 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow5_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow5_col3 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow6_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow6_col3 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow7_col0 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow7_col1 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow7_col2 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow7_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow8_col0 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow8_col1 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow8_col2 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow8_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow9_col0 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow9_col1 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow9_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow9_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }</style><table id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MW</th>        <th class="col_heading level0 col1" >LogP</th>        <th class="col_heading level0 col2" >NumHDonors</th>        <th class="col_heading level0 col3" >NumHAcceptors</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col0" class="data row0 col0" >276.295000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col1" class="data row0 col1" >3.296700</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col2" class="data row0 col2" >1.000000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow0_col3" class="data row0 col3" >3.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col0" class="data row1 col0" >569.592000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col1" class="data row1 col1" >2.373800</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col2" class="data row1 col2" >5.000000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow1_col3" class="data row1 col3" >6.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col0" class="data row2 col0" >569.592000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col1" class="data row2 col1" >2.373800</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col2" class="data row2 col2" >5.000000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow2_col3" class="data row2 col3" >6.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow3_col0" class="data row3 col0" >1473.536000</td>
#                         <td id="T_1d79c844_adb3_11ea_8378_6c96cfdbc89brow3_col1" class="data row3 col1" >-1.0806

# %%
df = pd.concat([df,df_lipinski], axis=1)

# %%
df.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL281470            COc1ccc(-c2[nH]nc3c2C(=O)c2ccccc2-3)cc1
# 1                NaN                                                NaN
# 2        CHEMBL13462  CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@@...
# 3       CHEMBL414123  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
# 4                NaN                                                NaN
#
#    standard_value bioactivity_class  norm_value     pIC50        MW    LogP  \
# 0        725000.0          inactive    725000.0  3.139662   276.295  3.2967
# 1             NaN               NaN         NaN       NaN   569.592  2.3738
# 2         16000.0          inactive     16000.0  4.795880   569.592  2.3738
# 3         15000.0          inactive     15000.0  4.823909  1473.536 -1.0806
# 4             NaN               NaN         NaN       NaN  1473.536 -1.0806
#
#    NumHDonors  NumHAcceptors
# 0         1.0            3.0
# 1         5.0            6.0
# 2         5.0            6.0
# 3        17.0           19.0
# 4        17.0           19.0

# %% [markdown]
# ### **Convert IC50 to pIC50**
# To allow **IC50** data to be more uniformly distributed, we will convert **IC50** to the negative logarithmic scale which is essentially **-log10(IC50)**.
#
# This custom function pIC50() will accept a DataFrame as input and will:
# * Take the IC50 values from the ``standard_value`` column and converts it from nM to M by multiplying the value by 10$^{-9}$
# * Take the molar value and apply -log10
# * Delete the ``standard_value`` column and create a new ``pIC50`` column

# %%
def pIC50(i):
    molar = i*(10**-9) # Converts nM to M
    pIC50 = -np.log10(molar)
    return pIC50

# %% [markdown]
# Point to note: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
df.standard_value.describe()
# Out:
# count      2159.000000
# mean       8816.954530
# std       33568.590524
# min           0.015000
# 25%           2.850000
# 50%          13.000000
# 75%         463.000000
# max      725000.000000
# Name: standard_value, dtype: float64

# %%
df['norm_value'] = df['standard_value'].map(lambda x: 100000000 if x> 100000000 else x)
df['pIC50'] = df['norm_value'].map(pIC50)

# %%
df.to_csv('abl_kinase-2.csv')

# %% [markdown]
# ### **Removing the 'intermediate' bioactivity class**
# Here, we will be removing the ``intermediate`` class from our data set.

# %%
df = df[df['bioactivity_class'] != 'intermediate']

# %%
df['bioactivity_class'].value_counts()
# Out:
# active      1756
# inactive     403
# Name: bioactivity_class, dtype: int64

# %% [markdown]
# ## **Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors**

# %%
plt.figure(figsize=(6.5, 8.5))

sns.countplot(x='bioactivity_class', data=df)
plt.xlabel('Bioactivity class', size=20, fontweight='bold')
plt.ylabel('Frequency', fontsize=20, fontweight='bold')
plt.xticks(size=15)
plt.yticks(size=15)
sns.set(style='ticks')
sns.despine(top=True)
plt.savefig('plot_bioactivity_class.png')

# %% [markdown]
# ### **Scatter plot of MW versus LogP**
#
# It can be seen that the 2 bioactivity classes are spanning similar chemical spaces as evident by the scatter plot of MW vs LogP.

# %%
selection = ['bioactivity_class','MW','LogP','NumHDonors','NumHAcceptors','pIC50']
sns.pairplot(df[selection], hue='bioactivity_class')
plt.savefig('Pairplot.png',dpi=300)

# %% [markdown]
# ## Statistical analysis | Mann-Whitney U Test

# %%
def mannwhitney_(active,inactive, descriptor):
  stat, p = mannwhitneyu(active,inactive)
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
for feature in selection[1:]: 
    print(f'Working on {feature} ')
    results=mannwhitney_(df[df['bioactivity_class'] != 'inactive'][feature],
                df[df['bioactivity_class'] ==  'inactive'][feature],
                feature)
    display(results)
# Out:
# Working on MW
#   Descriptor  Statistics         p  alpha                      Interpretation
# 0         MW    389383.5  0.000945   0.05  Different distribution (reject H0)
# Working on LogP
#   Descriptor  Statistics         p  alpha  \
# 0       LogP    422164.0  0.247121   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)
# Working on NumHDonors
#    Descriptor  Statistics         p  alpha                      Interpretation
# 0  NumHDonors    373545.0  0.000002   0.05  Different distribution (reject H0)
# Working on NumHAcceptors
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors    394712.5  0.002673   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)
# Working on pIC50
#   Descriptor  Statistics              p  alpha  \
# 0      pIC50         0.0  1.434204e-223   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)
