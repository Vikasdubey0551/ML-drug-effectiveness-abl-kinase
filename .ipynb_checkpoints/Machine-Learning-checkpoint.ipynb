# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#importing-the-libraries" data-toc-modified-id="importing-the-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>importing the libraries</a></span></li><li><span><a href="#Reading-the-data" data-toc-modified-id="Reading-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Reading the data</a></span></li><li><span><a href="#Exploratory-data-analysis-(EDA)" data-toc-modified-id="Exploratory-data-analysis-(EDA)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploratory data analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Pairplot-of-the-all-the-features" data-toc-modified-id="Pairplot-of-the-all-the-features-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Pairplot of the all the features</a></span></li><li><span><a href="#Pearson-correlation-and-feature-selection" data-toc-modified-id="Pearson-correlation-and-feature-selection-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Pearson correlation and feature selection</a></span></li><li><span><a href="#Class-distribution-in-Diabetes-dataset" data-toc-modified-id="Class-distribution-in-Diabetes-dataset-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Class distribution in Diabetes dataset</a></span></li></ul></li><li><span><a href="#Preparing-data-for-machine-learning" data-toc-modified-id="Preparing-data-for-machine-learning-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Preparing data for machine learning</a></span><ul class="toc-item"><li><span><a href="#Undersampling" data-toc-modified-id="Undersampling-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Undersampling</a></span></li></ul></li><li><span><a href="#Machine-learning-Models" data-toc-modified-id="Machine-learning-Models-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Machine learning Models</a></span><ul class="toc-item"><li><span><a href="#k-Nearest-Neighbors-(KNN)" data-toc-modified-id="k-Nearest-Neighbors-(KNN)-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>k-Nearest Neighbors (KNN)</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>K-fold cross validation</a></span></li></ul></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>K-fold cross validation</a></span></li></ul></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Decision Tree</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>K-fold cross validation</a></span></li><li><span><a href="#Feature-importance-in-Decision-trees" data-toc-modified-id="Feature-importance-in-Decision-trees-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Feature importance in Decision trees</a></span></li></ul></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Feature-importance-in-Random-Forest" data-toc-modified-id="Feature-importance-in-Random-Forest-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Feature importance in Random Forest</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Gradient Boosting</a></span><ul class="toc-item"><li><span><a href="#Feature-importance-in-Gradient-Boosting" data-toc-modified-id="Feature-importance-in-Gradient-Boosting-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Feature importance in Gradient Boosting</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.5.2"><span class="toc-item-num">6.5.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.5.3"><span class="toc-item-num">6.5.3&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#Support-Vector-Machine-(SVM)" data-toc-modified-id="Support-Vector-Machine-(SVM)-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Support Vector Machine (SVM)</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#Neural-Networks" data-toc-modified-id="Neural-Networks-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Neural Networks</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.7.1"><span class="toc-item-num">6.7.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.7.2"><span class="toc-item-num">6.7.2&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.8.1"><span class="toc-item-num">6.8.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-6.8.2"><span class="toc-item-num">6.8.2&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li><li><span><a href="#Feature-importance-in-XGBoost" data-toc-modified-id="Feature-importance-in-XGBoost-6.8.3"><span class="toc-item-num">6.8.3&nbsp;&nbsp;</span>Feature importance in XGBoost</a></span></li></ul></li></ul></li><li><span><a href="#Model-comparision" data-toc-modified-id="Model-comparision-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model comparision</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#In-Future" data-toc-modified-id="In-Future-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>In Future</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# **Classification of effectiveness of the drug based on Lipinski molecular descriptors for ABL-kinase using Machine learning classfiers**.

# %% [markdown]
# # importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sweetviz as sv
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import TomekLinks
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix


# %matplotlib inline

# %% [markdown]
# # Reading the data

# %%
csv_file='abl_kinase-data.csv'
df = pd.read_csv(csv_file,index_col=0)

# %%
df.head()
# Out:
#    index molecule_chembl_id  \
# 0      0       CHEMBL281470
# 2      2        CHEMBL13462
# 3      3       CHEMBL414123
# 6      6       CHEMBL413629
# 7      7       CHEMBL301845
#
#                                     canonical_smiles  standard_value  \
# 0            COc1ccc(-c2[nH]nc3c2C(=O)c2ccccc2-3)cc1        725000.0
# 2  CC(=O)N[C@@H](Cc1ccc(OP(=O)(O)O)cc1)C(=O)N[C@@...         16000.0
# 3  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...         15000.0
# 6  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...         13500.0
# 7  CC[C@H](NC(=O)[C@H](Cc1ccc(OP(=O)(O)O)cc1)NC(C...         15000.0
#
#   bioactivity_class        MW    LogP  NumHDonors  NumHAcceptors  norm_value  \
# 0          inactive   276.295  3.2967         1.0            3.0    725000.0
# 2          inactive   569.592  2.3738         5.0            6.0     16000.0
# 3          inactive  1473.536 -1.0806        17.0           19.0     15000.0
# 6          inactive  1507.544 -0.3251        17.0           18.0     13500.0
# 7          inactive   525.583  2.9190         4.0            5.0     15000.0
#
#       pIC50
# 0  3.139662
# 2  4.795880
# 3  4.823909
# 6  4.869666
# 7  4.823909

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
print("dimension of diabetes data: {}".format(df.shape))
# Out:
# dimension of diabetes data: (2159, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2159 entries, 0 to 2436
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               2159 non-null   int64
#  1   molecule_chembl_id  2159 non-null   object
#  2   canonical_smiles    2159 non-null   object
#  3   standard_value      2159 non-null   float64
#  4   bioactivity_class   2159 non-null   object
#  5   MW                  2159 non-null   float64
#  6   LogP                2159 non-null   float64
#  7   NumHDonors          2159 non-null   float64
#  8   NumHAcceptors       2159 non-null   float64
#  9   norm_value          2159 non-null   float64
#  10  pIC50               2159 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 202.4+ KB

# %% [markdown]
#  * Dataset is small and well labeled. There are no null values present.
#  * very suitable to supervised machine learning formulation.
#  * This is a binary classification problem, where we have 2 classes in the target **(y)** (i.e.`'bioactivity_class'`) and the Lipinski Molecular descriptors (i.e. `MW`,`LogP`,`NumHDonors` and `NumHAcceptors` can be used as the feature (**X**).

# %%
selection = ['MW','LogP','NumHDonors','NumHAcceptors','bioactivity_class']
df = df[selection]

# %% [markdown]
# ## Pairplot of the all the features

# %%
selection = ['bioactivity_class','MW','LogP','NumHDonors','NumHAcceptors']
sns.pairplot(df[selection], hue='bioactivity_class')
plt.tight_layout()

# %% [markdown]
# ## Pearson correlation and feature selection

# %%
plt.figure(figsize=(10,7))
corr_mat = df.iloc[:,:-1].corr()
sns.heatmap(corr_mat, fmt='0.2f', annot=True, lw=2, cbar_kws={'label':'Pearson Correlation (r)'})
plt.xticks(size=15,rotation=90)
plt.yticks(size=15,rotation=0)
plt.tight_layout()
plt.savefig('Correlation.png',dpi=300);

# %% [markdown]
# * All the features hold very little correlation amongst each other. Only **NumHAcceptors** and **Molecular weight** shows a significant  strong correlation. Therefore, keeping the all the features.

# %% [markdown]
# ## Class distribution in Diabetes dataset

# %%
plt.figure(figsize=(5,5))
sns.countplot(df['bioactivity_class'],label='Count')
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Outcome',size=15)
plt.xlabel('Count',size=15)
sns.despine(top=True)
plt.title('Class distribution',size=26, weight='bold')
plt.tight_layout()
plt.savefig('Class-distribution.png');

# %% [markdown]
# # Preparing data for machine learning

# %%
df['bioactivity_class'] = df['bioactivity_class'].map({'inactive':0, 'active':1})

# %%
X = df.iloc[:,:-1].values   ##features selection
y = df.iloc[:,-1].values    ## target selection

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=27)

# %% [markdown]
# * It is importannt to use stratify inside **train_test_split**. It keeps the same distribution of target same  within train and testing datasets. if variable `y` is a binary categorical variable with values 0 and 1 and there are 25% of zeros and 75% of ones, `stratify=y` will make sure that random split has 40% of 0's and 60% of 1's

# %%
# Out:
# '0.22.1'

# %% [markdown]
# ## Undersampling

# %%
tl = TomekLinks(sampling_strategy='auto')
X_train,y_train = tl.fit_resample(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f46f309a8c9a> in <module>
#       1 tl = TomekLinks(sampling_strategy='auto')
# ----> 2 X_train,y_train = tl.fit_resample(X_train,y_train)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imblearn/base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/imblearn/base.py in _check_X_y(self, X, y, accept_sparse)
#     132             accept_sparse = ["csr", "csc"]
#     133         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 134         X, y = self._validate_data(
#     135             X, y, reset=True, accept_sparse=accept_sparse
#     136         )
#
# AttributeError: 'TomekLinks' object has no attribute '_validate_data'

# %% [markdown]
# # Machine learning Models

# %% [markdown]
# ## k-Nearest Neighbors (KNN)

# %%
training_accuracy = [] 
test_accuracy = []
training_f1 = []
test_f1 = []

neighbors_settings = range(2,20)

for n_neighbors in neighbors_settings:
    print(f'working on neighbors {n_neighbors}')
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(X_train, y_train)
    
    y_train_pred=knn.predict(X_train)
    y_pred=knn.predict(X_test)
    
    training_accuracy.append(accuracy_score(y_train,y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_pred))
    
    training_f1.append(f1_score(y_train,y_train_pred))
    test_f1.append(f1_score(y_test, y_pred))
# Out:
# working on neighbors 2
# working on neighbors 3
# working on neighbors 4
# working on neighbors 5
# working on neighbors 6
# working on neighbors 7
# working on neighbors 8
# working on neighbors 9
# working on neighbors 10
# working on neighbors 11
# working on neighbors 12
# working on neighbors 13
# working on neighbors 14
# working on neighbors 15
# working on neighbors 16
# working on neighbors 17
# working on neighbors 18
# working on neighbors 19

# %%
fig = plt.figure(figsize=(14,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.add_subplot(2,2,1)
plt.plot(neighbors_settings, training_accuracy, label='training accuracy')
plt.plot(neighbors_settings, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy',size=20)
plt.xticks(range(2,20,2),size=15)
plt.yticks(size=15)
plt.xlabel('n_neighbors',size=20)
plt.title('Accuracy Score',size=20, weight='bold')
plt.legend([],frameon=False, prop={'size':20})

fig.add_subplot(2,2,2)
plt.plot(neighbors_settings, training_f1)
plt.plot(neighbors_settings, test_f1)
plt.xticks(range(2,20,2),size=15)
plt.yticks(size=15)
plt.ylabel('F1 Score',size=20)
plt.xlabel('n_neighbors',size=20)
plt.title('F1-Score',size=20,weight='bold')
plt.legend(['Training','Testing'],frameon=False, bbox_to_anchor=(0.2,-0.2), ncol=2, prop={'size':20});

# %% [markdown]
# `Accuracy score`, `F1-score` suggest that `n_neighbors=13` is the optimum choice **(by looking a testing accuracies)**.

# %%
knn = KNeighborsClassifier(n_neighbors=13).fit(X_train, y_train)
y_pred = knn.predict(X_test)

print('Accuracy of K-NN classifier on test set: {:.2f}'.format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'.format(accuracy_score(y_test, y_pred)))
print('F1-score of K-NN classifier on test set: {:.2f}'.format(f1_score(y_test, y_pred)))
# Out:
# Accuracy of K-NN classifier on test set: 0.84
# Accuracy of K-NN classifier on test set: 0.83
# F1-score of K-NN classifier on test set: 0.90

# %% [markdown]
# ### Confusion matrix

# %%
def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = conf_mat/counts
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat, 'kNN')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_knn_accuracy = cross_val_score(knn, X, y, cv=10) ##10-fold cross validation
k_fold_knn_f1 = cross_val_score(knn, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_knn_accuracy.mean().round(2)} +/- {k_fold_knn_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_knn_f1.mean().round(2)} +/- {k_fold_knn_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.78 +/- 0.06
# Average F1-score after 10 fold cross validation :0.52 +/- 0.05

# %% [markdown]
# ## Logistic Regression

# %%
plt.figure(figsize=(8,6))
Clist=[1,0.01,100]

for C in Clist : 

    logreg = LogisticRegression(C=C,solver='newton-cg').fit(X_train, y_train) #keeping C=1 a
    y_train_pred = logreg.predict(X_train)
    y_pred = logreg.predict(X_test)

    print('C : {} Training set accuracy: {:.3f}'.format(C,accuracy_score(y_train, y_train_pred)))
    print('C : {} Test set accuracy: {:.3f}'.format(C,accuracy_score(y_test, y_pred)))

    print('C : {} Training set F1-score: {:.3f}'.format(C,f1_score(y_train, y_train_pred)))
    print('C : {} Test set F1-score: {:.3f}'.format(C, f1_score(y_test, y_pred)))
    print('\n')
    
    data_features = [x for i,x in enumerate(df.columns[:-1]) if i!=8]
    plt.plot(logreg.coef_.T, marker='o', label=f"C={C}")

plt.xticks(range(df.shape[1]), diabetes_features, rotation=90)
plt.hlines(0, 0, df.shape[1])
plt.ylim(-5, 5)
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlabel("Feature",size=20)
plt.ylabel("Coefficient magnitude",size=15)
plt.legend(frameon=False)
# Out:
# C : 1 Training set accuracy: 0.812
# C : 1 Test set accuracy: 0.820
# C : 1 Training set F1-score: 0.896
# C : 1 Test set F1-score: 0.901
#
#
# C : 0.01 Training set accuracy: 0.813
# C : 0.01 Test set accuracy: 0.815
# C : 0.01 Training set F1-score: 0.897
# C : 0.01 Test set F1-score: 0.898
#
#
# C : 100 Training set accuracy: 0.812
# C : 100 Test set accuracy: 0.820
# C : 100 Training set F1-score: 0.896
# C : 100 Test set F1-score: 0.901

# %% [markdown]
# The default value of C=1 provides with 81% accuracy on training and 82% accuracy on test set.

# %% [markdown]
# Stronger regularization (`C=0.01`) pushes coefficients more and more toward zero. Inspecting the plot more closely suggests that feature `logP`, for `C=100`, `C=1` and `C=0.001`, the coefficient is **positive**. This indicates that high `LogP` feature is related to a sample being`diabetes`, regardless which model we look at.

# %% [markdown]
# ### Confusion matrix

# %%
logreg = LogisticRegression(C=1,solver='newton-cg').fit(X_train,y_train)
y_pred=logreg.predict(X_test)

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Logistic Regression')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_logreg_accuracy = cross_val_score(logreg, X, y, cv=10) ##10-fold cross validation
k_fold_logreg_f1 = cross_val_score(logreg, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation
# Out:
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_logreg_accuracy.mean().round(2)} +/- {k_fold_logreg_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_logreg_f1.mean().round(2)} +/- {k_fold_logreg_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.79 +/- 0.09
# Average F1-score after 10 fold cross validation :0.45 +/- 0.04

# %% [markdown]
# ## Decision Tree

# %%
max_depth=range(1,20)
training_accuracy = [] 
test_accuracy = []
training_f1 = []
test_f1 = []

for depth in max_depth : 
    tree = DecisionTreeClassifier(random_state=0, max_depth=depth, min_samples_leaf=1).fit(X_train, y_train)
    y_train_pred = tree.predict(X_train)
    y_pred = tree.predict(X_test)
    
    training_accuracy.append(accuracy_score(y_train,y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_pred))
    
    training_f1.append(f1_score(y_train,y_train_pred))
    test_f1.append(f1_score(y_test, y_pred))

# %%
fig = plt.figure(figsize=(14,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.add_subplot(2,2,1)
plt.plot(max_depth, training_accuracy, label='training accuracy')
plt.plot(max_depth, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy',size=20)
plt.xlabel('Max depth',size=20)
plt.xticks(range(1,20,2),size=15)
plt.yticks(size=15)
plt.title('Accuracy Score',size=20, weight='bold')
plt.legend([],frameon=False)

fig.add_subplot(2,2,2)
plt.plot(max_depth, training_f1)
plt.plot(max_depth, test_f1)
plt.ylabel('F1 Score',size=20)
plt.xlabel('Max depth',size=20)
plt.xticks(range(1,20,2),size=15)
plt.yticks(size=15)
plt.title('F1-Score',size=20,weight='bold')
plt.legend(['Training','Testing'],frameon=False, bbox_to_anchor=(0.3,-0.2), prop = {'size':20}, ncol=2);

# %% [markdown]
# The training accuracy on the after training set is 100%, while the test set accuracy is much worse. This means tree is  overfitting and not generalizing well to new data. We set `max_depth=7`, limiting the depth of the tree decreases overfitting. This leads to a lower accuracy on the training set, but an improvement on the test set.

# %%
tree = DecisionTreeClassifier(max_depth=4, min_samples_leaf=1, random_state=0).fit(X_train, y_train)
y_pred=tree.predict(X_test)

print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on test: 0.856
# F1-score on test set: 0.918

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Decision Tree')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_tree_accuracy = cross_val_score(tree, X, y, cv=10) ##10-fold cross validation
k_fold_tree_f1 = cross_val_score(tree, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation
# Out:
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_tree_accuracy.mean().round(2)} +/- {k_fold_tree_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_tree_f1.mean().round(2)} +/- {k_fold_tree_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.81 +/- 0.07
# Average F1-score after 10 fold cross validation :0.59 +/- 0.1

# %% [markdown]
# ### Feature importance in Decision trees
# Feature importance rates how important each feature is for the decision a tree makes. It is a number between 0 and 1
#
#      0 means “not used at all”
#      1 means “perfectly predicts the target”

# %%
def plot_feature_importances(model, figure):
    n_features = 4
    plt.figure(figsize=(10,6))
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), diabetes_features,size=15)
    plt.xticks(size=15)
    plt.xlabel('Feature importance',size=20,)
    #plt.ylabel('Feature',size=20)
    plt.ylim(-1, n_features)
    sns.despine(top=True)
    plt.title(f'{figure}',size=20)
    plt.tight_layout()
    plt.savefig(f'feature-image{figure}.png',dpi=300)

plot_feature_importances(tree,'Decision Tree')

# %% [markdown]
# Feature `LogP` is the most important feature.

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=0).fit(X_train, y_train)
y_pred=rf.predict(X_test)

print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on test: 0.889
# F1-score on test set: 0.934

# %% [markdown]
#  The default parameters of the random forest work well. This conclusion is derived after trying various values of  `max_depth` and `n_estimators`.

# %% [markdown]
# ### Feature importance in Random Forest

# %%
plot_feature_importances(rf, 'Random Forest')

# %% [markdown]
# Similarly to the single decision tree, the random forest also gives a lot of importance to the `LogP` feature and it also chooses `MW` to be the 2nd most informative feature.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Random Forest')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_rf_accuracy = cross_val_score(rf, X, y, cv=10) ##10-fold cross validation
k_fold_rf_f1 = cross_val_score(rf, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_tree_accuracy.mean().round(2)} +/- {k_fold_tree_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_tree_f1.mean().round(2)} +/- {k_fold_tree_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.81 +/- 0.07
# Average F1-score after 10 fold cross validation :0.59 +/- 0.1

# %% [markdown]
# ## Gradient Boosting

# %%
gb = GradientBoostingClassifier(random_state=0, max_depth=1, learning_rate=0.01).fit(X_train, y_train)
y_pred=gb.predict(X_test)

print("Accuracy on train: {:.3f}".format(gb.score(X_train, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.820
# Accuracy on test: 0.820
# F1-score on test set: 0.901

# %% [markdown]
# Default values result in **overfitting**. Therefore, `max_depth = 1` and `learning_rate = 0.01` is chosen which reduces the gap between training and test accuracy.

# %% [markdown]
# ### Feature importance in Gradient Boosting

# %%
plot_feature_importances(gb, 'Gradient Boosting')

# %% [markdown]
# Gradient Boosting gives the most importance to `LogP` and again 2nd best is `MW`.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Gradient Boosting')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_gb_accuracy = cross_val_score(gb, X, y, cv=10) ##10-fold cross validation
k_fold_gb_f1 = cross_val_score(gb, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation
# Out:
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_gb_accuracy.mean().round(2)} +/- {k_fold_gb_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_gb_f1.mean().round(2)} +/- {k_fold_gb_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.82 +/- 0.01
# Average F1-score after 10 fold cross validation :0.47 +/- 0.04

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

#SVM requiest feature scaling
svc = SVC(C=1000, gamma='auto').fit(X_train_scaled, y_train)
y_pred=svc.predict(X_test_scaled)

print("Accuracy on train: {:.3f}".format(svc.score(X_train_scaled, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.843
# Accuracy on test: 0.859
# F1-score on test set: 0.919

# %% [markdown]
# `C = 1000`, `gamma='auto'` gives the best performance and minimum **overfitting**.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'SVM')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_svm_accuracy = cross_val_score(svc, scaler.fit_transform(X), y, cv=10) ##10-fold cross validation
k_fold_svm_f1 = cross_val_score(svc, scaler.fit_transform(X), y, cv=10, scoring='f1_macro') ##10-fold cross validation
# Out:
# /Users/dubey/.local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_svm_accuracy.mean().round(2)} +/- {k_fold_svm_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_svm_f1.mean().round(2)} +/- {k_fold_svm_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.82 +/- 0.05
# Average F1-score after 10 fold cross validation : 0.58 +/- 0.1

# %% [markdown]
# ## Neural Networks

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

mlp = MLPClassifier(random_state=0, alpha=1, max_iter=2000).fit(X_train_scaled, y_train)
y_pred=mlp.predict(X_test_scaled)

print("Accuracy on train: {:.3f}".format(mlp.score(X_train_scaled, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.850
# Accuracy on test: 0.861
# F1-score on test set: 0.921

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Neural Networks')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_mlp_accuracy = cross_val_score(mlp, scaler.fit_transform(X), y, cv=10) ##10-fold cross validation
k_fold_mlp_f1 = cross_val_score(mlp, scaler.fit_transform(X), y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_mlp_accuracy.mean().round(2)} +/- {k_fold_mlp_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_mlp_f1.mean().round(2)} +/- {k_fold_mlp_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.82 +/- 0.07
# Average F1-score after 10 fold cross validation : 0.63 +/- 0.09

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBClassifier(random_state=0, learning_rate =0.01,n_estimators=100, max_depth=5,gamma=1).fit(X_train,y_train)

y_pred=xgb.predict(X_test)

print("Accuracy on train: {:.3f}".format(xgb.score(X_train, y_train)))
print("Accuracy on test: {:.3f}".format(xgb.score(X_test, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.872
# Accuracy on test: 0.850
# F1-score on test set: 0.914

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'XGBoost')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_xgb_accuracy = cross_val_score(xgb, X, y, cv=10) ##10-fold cross validation
k_fold_xgb_f1 = cross_val_score(xgb, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_xgb_accuracy.mean().round(2)} +/- {k_fold_xgb_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_xgb_f1.mean().round(2)} +/- {k_fold_xgb_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.81 +/- 0.06
# Average F1-score after 10 fold cross validation : 0.6 +/- 0.09

# %% [markdown]
# ### Feature importance in XGBoost

# %%
plot_feature_importances(xgb, 'XGBoost')

# %% [markdown]
# # Model comparision

# %%
all_accuracies = [k_fold_knn_accuracy.mean().round(2),
                   k_fold_logreg_accuracy.mean().round(2),
                   k_fold_tree_accuracy.mean().round(2),
                   k_fold_rf_accuracy.mean().round(2),
                   k_fold_gb_accuracy.mean().round(2),
                   k_fold_svm_accuracy.mean().round(2),
                   k_fold_mlp_accuracy.mean().round(2),
                   k_fold_xgb_accuracy.mean().round(2)]

all_accuracies_errors = [k_fold_knn_accuracy.std().round(2),
                   k_fold_logreg_accuracy.std().round(2),
                   k_fold_tree_accuracy.std().round(2),
                   k_fold_rf_accuracy.std().round(2),
                   k_fold_gb_accuracy.std().round(2),
                   k_fold_svm_accuracy.std().round(2),
                   k_fold_mlp_accuracy.std().round(2),
                   k_fold_xgb_accuracy.std().round(2)]

# %%
all_f1 = [k_fold_knn_accuracy.mean().round(2),
                   k_fold_logreg_f1.mean().round(2),
                   k_fold_tree_f1.mean().round(2),
                   k_fold_rf_f1.mean().round(2),
                   k_fold_gb_f1.mean().round(2),
                   k_fold_svm_f1.mean().round(2),
                   k_fold_mlp_f1.mean().round(2),
                   k_fold_xgb_f1.mean().round(2)]

all_f1_errors = [k_fold_knn_f1.std().round(2),
                   k_fold_logreg_f1.std().round(2),
                   k_fold_tree_f1.std().round(2),
                   k_fold_rf_f1.std().round(2),
                   k_fold_gb_f1.std().round(2),
                   k_fold_svm_f1.std().round(2),
                   k_fold_mlp_f1.std().round(2),
                   k_fold_xgb_f1.std().round(2)]

# %%
models=['kNN','Logistic Regression','Decision Tree','Random Forest','Gradient Boosting','SVM','Neural Networks', 'XGBoost']

# %%
model_data = pd.DataFrame([all_accuracies,all_accuracies_errors,all_f1,all_f1_errors],columns=models, index = ['Accuracy','STD_acc','F1-macro','STD_f1']).T

# %%
model_data.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style  type="text/css" >
#     #T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col1 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col1 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col0 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col1 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col2 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col2 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow5_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow5_col1 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow5_col2 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow5_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow6_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow6_col1 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow6_col2 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow6_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow7_col0 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow7_col1 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow7_col2 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_9076858e_add2_11ea_827e_6c96cfdbc89brow7_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }</style><table id="T_9076858e_add2_11ea_827e_6c96cfdbc89b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >STD_acc</th>        <th class="col_heading level0 col2" >F1-macro</th>        <th class="col_heading level0 col3" >STD_f1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9076858e_add2_11ea_827e_6c96cfdbc89blevel0_row0" class="row_heading level0 row0" >kNN</th>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col0" class="data row0 col0" >0.780000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col1" class="data row0 col1" >0.060000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col2" class="data row0 col2" >0.780000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow0_col3" class="data row0 col3" >0.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_9076858e_add2_11ea_827e_6c96cfdbc89blevel0_row1" class="row_heading level0 row1" >Logistic Regression</th>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col0" class="data row1 col0" >0.790000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col1" class="data row1 col1" >0.090000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col2" class="data row1 col2" >0.450000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow1_col3" class="data row1 col3" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_9076858e_add2_11ea_827e_6c96cfdbc89blevel0_row2" class="row_heading level0 row2" >Decision Tree</th>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col0" class="data row2 col0" >0.810000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col1" class="data row2 col1" >0.070000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col2" class="data row2 col2" >0.590000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow2_col3" class="data row2 col3" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_9076858e_add2_11ea_827e_6c96cfdbc89blevel0_row3" class="row_heading level0 row3" >Random Forest</th>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col0" class="data row3 col0" >0.790000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col1" class="data row3 col1" >0.100000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col2" class="data row3 col2" >0.650000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow3_col3" class="data row3 col3" >0.090000</td>
#             </tr>
#             <tr>
#                         <th id="T_9076858e_add2_11ea_827e_6c96cfdbc89blevel0_row4" class="row_heading level0 row4" >Gradient Boosting</th>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col0" class="data row4 col0" >0.820000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col1" class="data row4 col1" >0.010000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col2" class="data row4 col2" >0.470000</td>
#                         <td id="T_9076858e_add2_11ea_827e_6c96cfdbc89brow4_col3" class="data row4 col3" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_9076858e_add2_11ea_827e_6c96cfdbc89blevel0_row5" class="row_headi

# %%
color=sns.color_palette('Set2')
model_data[['Accuracy','F1-macro']].plot.barh(figsize=(10,7),color=color)
plt.legend(frameon=False,bbox_to_anchor=(1,0.8), prop={'size':20})
plt.xticks(size=15)
plt.yticks(size=15)
#plt.xlim([0.65,0.8]);
plt.title('Model performances in measuring Drug effectivenss',size=20)
sns.despine(top=True)
plt.tight_layout()
plt.savefig('model-comparision.png',dpi=300)

# %%
plt.figure(figsize=(10,7))
drug_accuracy = [0.16, 0.04, 0.27, 0.57, 0.04, 0.30, 0.26, 0.27]
plt.barh(models,drug_accuracy,alpha=0.5)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('Accuracy in Drug non-Effectiveness',size=20)
sns.despine(top=True)
plt.tight_layout()
plt.savefig('drug-effectiveness.png',dpi=300)

# %% [markdown]
# # Conclusion

# %% [markdown]
# * All model seems to provide the great performance based on **10-fold cross validation** of the dataset. **Neural Network** achieves a highest **F1-score 0.63** , which is better metric for model evalution.
# * From the confusion matricies, decision tree has the highest success in detecting the drug effectiveness.
# * **Feature selection** suggests the `LogP` and `MW` are the most crucial factor for the successful prediction of diabetes.

# %% [markdown]
# #  In Future

# %% [markdown]
# * More hyperparameter tuning.
# * More classifiers such as `catboost` to improve the performance.
# * Generating a Tableau Dashboard
